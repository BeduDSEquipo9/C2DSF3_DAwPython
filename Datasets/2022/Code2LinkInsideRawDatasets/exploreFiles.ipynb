# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('airbnb_2022_6cities.csv')
# Out:
# /tmp/ipykernel_10648/1145364669.py:1: DtypeWarning: Columns (0,2,22,28,36,41,45,46,55,61,67) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('airbnb_2022_6cities.csv')

# %%
df.head(10)
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0    13247    https://www.airbnb.com/rooms/13247  20220320051201   2022-03-20
# 1   205894   https://www.airbnb.com/rooms/205894  20220320051201   2022-03-20
# 2  2444202  https://www.airbnb.com/rooms/2444202  20220320051201   2022-03-20
# 3  3325306  https://www.airbnb.com/rooms/3325306  20220320051201   2022-03-20
# 4  4244593  https://www.airbnb.com/rooms/4244593  20220320051201   2022-03-20
# 5  6609546  https://www.airbnb.com/rooms/6609546  20220320051201   2022-03-20
# 6  6677469  https://www.airbnb.com/rooms/6677469  20220320051201   2022-03-20
# 7  6764572  https://www.airbnb.com/rooms/6764572  20220320051201   2022-03-20
# 8  6990904  https://www.airbnb.com/rooms/6990904  20220320051201   2022-03-20
# 9  7875315  https://www.airbnb.com/rooms/7875315  20220320051201   2022-03-20
#
#                                             name  \
# 0                      Back Bay studio apartment
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of              id                           listing_url       scrape_id  \
# 0         13247    https://www.airbnb.com/rooms/13247  20220320051201
# 1        205894   https://www.airbnb.com/rooms/205894  20220320051201
# 2       2444202  https://www.airbnb.com/rooms/2444202  20220320051201
# 3       3325306  https://www.airbnb.com/rooms/3325306  20220320051201
# 4       4244593  https://www.airbnb.com/rooms/4244593  20220320051201
# ...         ...                                   ...             ...
# 149551   155859   https://www.airbnb.com/rooms/155859  20221220053924
# 149552   164069   https://www.airbnb.com/rooms/164069  20221220053924
# 149553   174808   https://www.airbnb.com/rooms/174808  20221220053924
# 149554   175608   https://www.airbnb.com/rooms/175608  20221220053924
# 149555   178395   https://www.airbnb.com/rooms/178395  20221220053924
#
#        last_scraped                                               name  \
# ...

# %%
df_raw.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
df['id']=pd.to_numeric(df['id'], errors='coerce')

# %%
df_sorted=df.sort_values(by='id', ascending=True, na_position='last')

# %%
df_sorted
# Out:
#             id                        listing_url       scrape_id  \
# 37669    109.0   https://www.airbnb.com/rooms/109  20221206172243
# 132760   958.0   https://www.airbnb.com/rooms/958  20221204162417
# 9199    2384.0  https://www.airbnb.com/rooms/2384  20221220053909
# 85436   2539.0  https://www.airbnb.com/rooms/2539  20220907064715
# 90054   2595.0  https://www.airbnb.com/rooms/2595  20221204162430
# ...        ...                                ...             ...
# 59105      NaN                     within an hour            100%
# 65974      NaN                     within an hour            100%
# 66352      NaN                     within an hour            100%
# 97606      NaN                                NaN             NaN
# 123557     NaN                       within a day             50%
#
#        last_scraped                                               name  \
# 37669    2022-12-07  Amazing bright elegant condo park front *UPGRA...
# ...
